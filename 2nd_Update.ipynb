# %%
import pandas as pd

data = pd.read_csv('companies.csv')

# %% [markdown]
# ## 1) Data Exploration

# %%
print("First 5 rows of the dataset:")
data.head()
# Out:
# First 5 rows of the dataset:
#         id  Unnamed: 0.1 entity_type  entity_id  parent_id  \
# 0      c:1             0     Company          1        NaN
# 1     c:10             1     Company         10        NaN
# 2    c:100             2     Company        100        NaN
# 3  c:10000             3     Company      10000        NaN
# 4  c:10001             4     Company      10001        NaN
#
#                  name     normalized_name                    permalink  \
# 0            Wetpaint            wetpaint            /company/wetpaint
# 1             Flektor             flektor             /company/flektor
# 2               There               there               /company/there
# 3             MYWEBBO             mywebbo             /company/mywebbo
# 4  THE Movie Streamer  the movie streamer  /company/the-movie-streamer
#
#      category_code     status  ... first_milestone_at last_milestone_at  \
# 0              web  operating  ...         2010-09-05        2013-09-18
# ...

# %%
# Get basic info about the dataset (number of non-null entries, data types, etc.)
print("\nDataset Info:")
data.info()
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196553 entries, 0 to 196552
# Data columns (total 44 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   196553 non-null  object
#  1   Unnamed: 0.1         196553 non-null  int64
#  2   entity_type          196553 non-null  object
#  3   entity_id            196553 non-null  int64
#  4   parent_id            0 non-null       float64
#  5   name                 196530 non-null  object
#  6   normalized_name      196527 non-null  object
#  7   permalink            196553 non-null  object
#  8   category_code        123186 non-null  object
#  9   status               196553 non-null  object
#  10  founded_at           91227 non-null   object
#  11  closed_at            2620 non-null    object
#  12  domain               126545 non-null  object
#  13  homepage_url         126545 non-null  object
# ...

# %%
# Get summary statistics for numerical columns
print("\nSummary statistics (numerical):")
data.describe()
# Out:
# Summary statistics (numerical):
#         Unnamed: 0.1      entity_id  parent_id     logo_width    logo_height  \
# count  196553.000000  196553.000000        0.0  110110.000000  110110.000000
# mean    98276.000000  153006.227333        NaN     459.132685     222.728917
# std     56740.108067   90209.250941        NaN     594.982577     333.090722
# min         0.000000       1.000000        NaN       1.000000       1.000000
# 25%     49138.000000   59850.000000        NaN     192.000000      70.000000
# 50%     98276.000000  174539.000000        NaN     267.000000     105.000000
# 75%    147414.000000  232655.000000        NaN     484.000000     232.000000
# max    196552.000000  286215.000000        NaN   18200.000000    9600.000000
#
#        investment_rounds  invested_companies  funding_rounds  \
# count        2591.000000         2591.000000    31707.000000
# mean            2.372057            2.204940        1.659760
# ...

# %%
# Get summary statistics for categorical columns
print("\nSummary statistics (categorical):")
data.describe(include=['object'])
# Out:
# Summary statistics (categorical):
#             id entity_type    name normalized_name           permalink  \
# count   196553      196553  196530          196527              196553
# unique  196553           1  196347          195451              196512
# top        c:1     Company       L               l  /company/bboescape
# freq         1      196553       8               9                   3
#
#        category_code     status  founded_at   closed_at            domain  \
# count         123186     196553       91227        2620            126545
# unique            42          4        6156         925            125498
# top         software  operating  2011-01-01  2012-01-01  placeshilton.com
# freq           17922     183441        3748         176                44
#
#         ...   region first_investment_at last_investment_at first_funding_at  \
# count   ...   196553                2583               2583            31507
# ...

# %%
# Get the shape of the dataset
print(f"\nDataset shape (rows, columns): {data.shape}")

# Get the column names
print("\nColumn names:")
data.columns
# Out:
# Dataset shape (rows, columns): (196553, 44)
#
# Column names:
# Index(['id', 'Unnamed: 0.1', 'entity_type', 'entity_id', 'parent_id', 'name',
#        'normalized_name', 'permalink', 'category_code', 'status', 'founded_at',
#        'closed_at', 'domain', 'homepage_url', 'twitter_username', 'logo_url',
#        'logo_width', 'logo_height', 'short_description', 'description',
#        'overview', 'tag_list', 'country_code', 'state_code', 'city', 'region',
#        'first_investment_at', 'last_investment_at', 'investment_rounds',
#        'invested_companies', 'first_funding_at', 'last_funding_at',
#        'funding_rounds', 'funding_total_usd', 'first_milestone_at',
#        'last_milestone_at', 'milestones', 'relationships', 'created_by',
#        'created_at', 'updated_at', 'lat', 'lng', 'ROI'],
#       dtype='object')

# %%
# Check for missing values in each column
print("\nMissing values in each column:")
print(data.isnull().sum())

# Check for missing values percentage in each column
print("\nMissing values percentage in each column:")
missing_percentage = (data.isnull().sum() / data.shape[0]) * 100
print(missing_percentage)

# Visualizing missing values with a heatmap
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.heatmap(data.isnull(), cbar=False, cmap='viridis')
plt.title("Missing Values Heatmap")
plt.show()
# Out:
# Missing values in each column:
# id                          0
# Unnamed: 0.1                0
# entity_type                 0
# entity_id                   0
# parent_id              196553
# name                       23
# normalized_name            26
# permalink                   0
# category_code           73367
# status                      0
# founded_at             105326
# closed_at              193933
# domain                  70008
# homepage_url            70008
# twitter_username       115962
# logo_url                86443
# logo_width              86443
# logo_height             86443
# short_description      189422
# description            104505
# overview                69582
# tag_list               115101
# country_code           108563
# state_code             145650
# city                   112663
# region                      0
# first_investment_at    193970
# last_investment_at     193970
# investment_rounds      193962
# invested_companies     193962
# ...

# %%
# Check for duplicate rows
print("\nNumber of duplicate rows:")
print(data.duplicated().sum())
# Out:
# Number of duplicate rows:
# 0

# %%
# Display duplicate rows (if any)
print("\nDuplicate rows:")
print(data[data.duplicated()])
# Out:
# Duplicate rows:
# Empty DataFrame
# Columns: [id, Unnamed: 0.1, entity_type, entity_id, parent_id, name, normalized_name, permalink, category_code, status, founded_at, closed_at, domain, homepage_url, twitter_username, logo_url, logo_width, logo_height, short_description, description, overview, tag_list, country_code, state_code, city, region, first_investment_at, last_investment_at, investment_rounds, invested_companies, first_funding_at, last_funding_at, funding_rounds, funding_total_usd, first_milestone_at, last_milestone_at, milestones, relationships, created_by, created_at, updated_at, lat, lng, ROI]
# Index: []
#
# [0 rows x 44 columns]

# %%
# Get data types of each column
print("\nColumn data types:")
print(data.dtypes)
# Out:
# Column data types:
# id                             object
# Unnamed: 0.1                    int64
# entity_type                    object
# entity_id                       int64
# parent_id                     float64
# name                           object
# normalized_name                object
# permalink                      object
# category_code                  object
# status                         object
# founded_at                     object
# closed_at                      object
# domain                         object
# homepage_url                   object
# twitter_username               object
# logo_url                       object
# logo_width                    float64
# logo_height                   float64
# short_description              object
# description                    object
# overview                       object
# tag_list                       object
# country_code                   object
# state_code                     object
# ...

# %%
data['created_at'] = pd.to_datetime(data['created_at'])
data['updated_at'] = pd.to_datetime(data['updated_at'])

# %%
data
# Out:
#              id  Unnamed: 0.1 entity_type  entity_id  parent_id  \
# 0           c:1             0     Company          1        NaN
# 1          c:10             1     Company         10        NaN
# 2         c:100             2     Company        100        NaN
# 3       c:10000             3     Company      10000        NaN
# 4       c:10001             4     Company      10001        NaN
# ...         ...           ...         ...        ...        ...
# 196548  c:99940        196548     Company      99940        NaN
# 196549   c:9995        196549     Company       9995        NaN
# 196550   c:9996        196550     Company       9996        NaN
# 196551   c:9997        196551     Company       9997        NaN
# 196552   c:9998        196552     Company       9998        NaN
#
#                       name     normalized_name                    permalink  \
# 0                 Wetpaint            wetpaint            /company/wetpaint
# ...

# %%
data.columns
# Out:
# Index(['id', 'Unnamed: 0.1', 'entity_type', 'entity_id', 'parent_id', 'name',
#        'normalized_name', 'permalink', 'category_code', 'status', 'founded_at',
#        'closed_at', 'domain', 'homepage_url', 'twitter_username', 'logo_url',
#        'logo_width', 'logo_height', 'short_description', 'description',
#        'overview', 'tag_list', 'country_code', 'state_code', 'city', 'region',
#        'first_investment_at', 'last_investment_at', 'investment_rounds',
#        'invested_companies', 'first_funding_at', 'last_funding_at',
#        'funding_rounds', 'funding_total_usd', 'first_milestone_at',
#        'last_milestone_at', 'milestones', 'relationships', 'created_by',
#        'created_at', 'updated_at', 'lat', 'lng', 'ROI'],
#       dtype='object')

# %%
data.dropna(subset=['first_milestone_at','last_milestone_at'],inplace=True)

# %%
data.drop(columns=['Unnamed: 0.1','entity_type','parent_id	'])

# %%
len(data.category_code.unique())
# Out:
# 43

# %%
len(data.status.unique())
# Out:
# 4

# %%
for i in data.columns:
    print(f"{len(data[i].unique())} name : {i} ")
# Out:
# 91699 name : id
# 91699 name : Unnamed: 0.1
# 1 name : entity_type
# 91699 name : entity_id
# 1 name : parent_id
# 91646 name : name
# 91306 name : normalized_name
# 91688 name : permalink
# 43 name : category_code
# 4 name : status
# 4133 name : founded_at
# 568 name : closed_at
# 50331 name : domain
# 50450 name : homepage_url
# 38250 name : twitter_username
# 48843 name : logo_url
# 2812 name : logo_width
# 1777 name : logo_height
# 4120 name : short_description
# 37647 name : description
# 51250 name : overview
# 35158 name : tag_list
# 139 name : country_code
# 52 name : state_code
# 5714 name : city
# 3398 name : region
# 757 name : first_investment_at
# 699 name : last_investment_at
# 42 name : investment_rounds
# 38 name : invested_companies
# 2845 name : first_funding_at
# 2509 name : last_funding_at
# 16 name : funding_rounds
# 5454 name : funding_total_usd
# 4080 name : first_milestone_at
# 3966 name : last_milestone_at
# 9 name : milestones
# 153 name : relationships
# ...

# %%
data = data.drop_duplicates()

numerical_columns = data.select_dtypes(include=['float64', 'int64']).columns
data[numerical_columns] = data[numerical_columns].fillna(data[numerical_columns].median())

categorical_columns = data.select_dtypes(include=['object']).columns
data[categorical_columns] = data[categorical_columns].fillna(data[categorical_columns].mode().iloc[0])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoders = {}
for column in categorical_columns:
    le = LabelEncoder()
    data[column] = le.fit_transform(data[column])
    label_encoders[column] = le

# %%
data.columns
# Out:
# Index(['id', 'Unnamed: 0.1', 'entity_type', 'entity_id', 'parent_id', 'name',
#        'normalized_name', 'permalink', 'category_code', 'status', 'founded_at',
#        'closed_at', 'domain', 'homepage_url', 'twitter_username', 'logo_url',
#        'logo_width', 'logo_height', 'short_description', 'description',
#        'overview', 'tag_list', 'country_code', 'state_code', 'city', 'region',
#        'first_investment_at', 'last_investment_at', 'investment_rounds',
#        'invested_companies', 'first_funding_at', 'last_funding_at',
#        'funding_rounds', 'funding_total_usd', 'first_milestone_at',
#        'last_milestone_at', 'milestones', 'relationships', 'created_by',
#        'created_at', 'updated_at', 'lat', 'lng', 'ROI'],
#       dtype='object')

# %%
target_column = 'status'
X = data.drop(target_column, axis=1) 
y = data[target_column]
